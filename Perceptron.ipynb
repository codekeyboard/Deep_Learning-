# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,
                           n_classes=2,n_clusters_per_class=1, random_state=41, hypercube=False, class_sep=10)

# %%
plt.figure(figsize=(10,8))
plt.scatter(X[:,0],X[:,1], c=y , cmap='winter', s=100)

# %%
epochs = 1000
def Perceptron(X,y):
  lr =0.1
  X = np.insert(X,0,1,axis=1) #add 1 at 0 column
  weights = np.zeros(X.shape[1]) #which is = 2
  for i in range(epochs):
    j = np.random.randint(0,X.shape[0])
    y_hat = step(np.dot(X[j],weights))
    weights  = weights + lr*(y[j]-y_hat)*X[j]
  print(weights)
  return weights[0],weights[1:]

# %%
def step(z):
  if z>0:
    return 1
  else:
    return 0

# %%
intercept_,coef_= Perceptron(X,y)
# Out:
# [0.4        0.57332068 0.05631323]

# %%
intercept_,coef_
# Out:
# (0.4, array([0.57332068, 0.05631323]))

# %% [markdown]
# in order to use  y = mx +b we can easily get slope m and intecept b

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
m,b
# Out:
# (-10.18092297373091, -7.103126250984615)

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input +b

# %%
plt.figure(figsize = (10,6))
plt.plot(x_input,y_input, color = 'red',linewidth=3)
plt.scatter(X[:,0],X[:,1], c=y, cmap='winter')
plt.show()
